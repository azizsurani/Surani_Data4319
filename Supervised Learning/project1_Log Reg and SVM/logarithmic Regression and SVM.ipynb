# %%
# import packages
import numpy as np # NumPy is a Python package that stands for ‘Numerical Python’. It is the core library for scientific computing
import pandas as pd # Pandas is used for data manipulation, analysis and cleaning.
import matplotlib.pyplot as plt # powerful plotting library for python that offers a varied spectrum of 1D, 2D, and 3D visualizations. 
from IPython.display import display, HTML, display_html # Display the HTML representation of an object.
import seaborn as sns # Seaborn is a data visualization library in Python based on matplotl

# %% [markdown]
# # Data Analysis and Data Visualisation

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
from pandas import read_csv #  imports a CSV file to DataFrame format.
dataset_diabetes = read_csv('diabetes.csv')# read csv

# %%
dataset_diabetes.head() # return top n (5 by default) rows of a data frame
# Out:
#    Age  Gender  Polyuria  Polydipsia  sudden weight loss  Polyphagia  \
# 0   40       1         0           1                   0           0
# 1   58       1         0           0                   0           0
# 2   41       1         1           0                   0           1
# 3   45       1         0           0                   1           1
# 4   60       1         1           1                   1           1
#
#    Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 0               0                0        1             0                1
# 1               0                1        0             0                0
# 2               0                0        1             0                1
# 3               1                0        1             0                1
# 4               0                1        1             1                1
#
#    partial paresis  muscle stiffness  Alopecia  class
# 0                0                 1         1      1
# 1                1                 0         1      1
# 2                0                 1         1      1
# 3                0                 0         0      1
# 4                1                 1         1      1

# %%
dataset_diabetes.tail() #  return bottom n (5 by default) rows of a data frame
# Out:
#      Age  Gender  Polyuria  Polydipsia  sudden weight loss  Polyphagia  \
# 246   39       0         1           1                   1           1
# 247   48       0         1           1                   1           1
# 248   58       0         1           1                   1           1
# 249   32       0         0           0                   0           0
# 250   42       1         0           0                   0           0
#
#      Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 246               0                0        1             0                1
# 247               0                0        1             1                1
# 248               0                1        0             0                0
# 249               0                1        1             0                1
# 250               0                0        0             0                0
#
#      partial paresis  muscle stiffness  Alopecia  class
# 246                1                 0         0      1
# 247                1                 0         0      1
# 248                1                 1         0      1
# 249                0                 0         1      0
# 250                0                 0         0      0

# %%
dataset_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 15 columns):
# Age                   251 non-null int64
# Gender                251 non-null int64
# Polyuria              251 non-null int64
# Polydipsia            251 non-null int64
# sudden weight loss    251 non-null int64
# Polyphagia            251 non-null int64
# Genital thrush        251 non-null int64
# visual blurring       251 non-null int64
# Itching               251 non-null int64
# Irritability          251 non-null int64
# delayed healing       251 non-null int64
# partial paresis       251 non-null int64
# muscle stiffness      251 non-null int64
# Alopecia              251 non-null int64
# class                 251 non-null int64
# dtypes: int64(15)
# memory usage: 29.5 KB

# %%
dataset_diabetes.shape # rows, columns
# Out:
# (251, 15)

# %%
display(dataset_diabetes.iloc[:,:].dtypes)
# Out:
# Age                   int64
# Gender                int64
# Polyuria              int64
# Polydipsia            int64
# sudden weight loss    int64
# Polyphagia            int64
# Genital thrush        int64
# visual blurring       int64
# Itching               int64
# Irritability          int64
# delayed healing       int64
# partial paresis       int64
# muscle stiffness      int64
# Alopecia              int64
# class                 int64
# dtype: object

# %%
display(dataset_diabetes.iloc[:,:].isnull().any()) # which column has null values (missing values)
# Out:
# Age                   False
# Gender                False
# Polyuria              False
# Polydipsia            False
# sudden weight loss    False
# Polyphagia            False
# Genital thrush        False
# visual blurring       False
# Itching               False
# Irritability          False
# delayed healing       False
# partial paresis       False
# muscle stiffness      False
# Alopecia              False
# class                 False
# dtype: bool

# %%
type(dataset_diabetes)
# Out:
# pandas.core.frame.DataFrame

# %%
len(dataset_diabetes) # size of the dataset
# Out:
# 251

# %%
dataset_diabetes.shape # rows, columns
# Out:
# (251, 15)

# %%
pd.DataFrame.drop_duplicates(dataset_diabetes)
# Out:
#      Age  Gender  Polyuria  Polydipsia  sudden weight loss  Polyphagia  \
# 0     40       1         0           1                   0           0
# 1     58       1         0           0                   0           0
# 2     41       1         1           0                   0           1
# 3     45       1         0           0                   1           1
# 4     60       1         1           1                   1           1
# 5     55       1         1           1                   0           1
# 6     57       1         1           1                   0           1
# 7     66       1         1           1                   1           0
# 8     67       1         1           1                   0           1
# 9     70       1         0           1                   1           1
# 10    44       1         1           1                   0           0
# 11    38       1         1           1                   0           1
# 12    35       1         1           0                   0           1
# 13    61       1         1           1                   1           1
# 14    60       1         1           1                   0           1
# 15    58       1         1           1                   0           1
# 16    54       1         1           1                   1           0
# 17    67       1         0           1                   0           1
# 18    66       1         1           1                   0           1
# 19    43       1         1           1                   1           0
# 20    62       1         1           1                   0           1
# 21    54       1         1           1                   1           1
# 22    39       1         1           0                   1           0
# 23    48       1         0           1                   1           0
# 24    58       1         1           1                   1           1
# 25    32       1         0           0                   0           0
# 26    42       1         0           0                   0           1
# 27    52       1         1           1                   1           1
# 28    38       1         0           1                   0           0
# 29    53       1         1           1                   1           1
# ..   ...     ...       ...         ...                 ...         ...
# 220   34       0         0           0                   0           0
# 221   64       1         0           0                   0           1
# 222   44       1         1           0                   1           0
# 223   36       1         0           0                   0           0
# 224   43       1         0           0                   0           0
# 225   53       1         0           0                   0           0
# 226   47       1         0           0                   0           0
# 227   58       1         0           1                   0           0
# 228   56       1         0           0                   1           1
# 229   51       0         0           0                   0           0
# 230   59       0         0           0                   0           0
# 231   50       0         0           0                   0           0
# 232   66       1         1           0                   1           0
# 233   67       1         0           0                   0           1
# 234   70       1         1           0                   0           1
# 235   44       1         0           0                   0           0
# 237   61       1         0           0                   0           0
# 238   60       1         0           0                   1           0
# 239   58       1         0           0                   0           0
# 240   54       1         0           0                   0           0
# 241   67       1         0           0                   0           0
# 242   66       1         0           0                   0           1
# 243   43       1         0           0                   0           0
# 244   62       0         1           1                   1           0
# 245   54       0         1           1                   1           1
# 246   39       0         1           1                   1           1
# 247   48       0         1           1                   1           1
# 248   58       0         1           1                   1           1
# 249   32       0         0           0                   0           0
# 250   42       1         0           0                   0           0
#
#      Genital thrush  visual blurring  Itching  Irritability  delayed healing  \
# 0                 0                0        1             0                1
# 1                 0                1        0             0                0
# 2                 0                0        1             0                1
# 3                 1                0        1             0                1
# 4                 0                1        1             1                1
# 5                 0                1        1             0                1
# 6                 1                0        0             0                1
# 7                 0                1        1             1                0
# 8                 1                0        1             1                0
# 9                 0                1        1             1                0
# 10                1                0        0             1                1
# 11                1                0        1             0                1
# 12                1                0        0             1                1
# 13                1                1        1             0                0
# 14                0                1        1             0                1
# 15                0                0        0             0                1
# 16                1                0        0             0                1
# 17                0                1        0             1                1
# 18                0                1        0             0                0
# 19                1                0        0             0                0
# 20                0                1        0             1                0
# 21                1                1        1             0                1
# 22                1                0        1             1                0
# 23                0                1        1             1                1
# 24                0                1        0             0                1
# 25                1                0        0             1                1
# 26                0                0        0             1                0
# 27                0                1        1             0                1
# 28                1                0        0             0                0
# 29                0                1        0             1                0
# ..              ...              ...      ...           ...              ...
# 220               0                0        0             0                0
# 221               0                1        1             1                1
# 222               1                0        1             0                1
# 223               0                0        0             0                0
# 224               1                0        1             0                0
# 225               0                1        1             0                1
# 226               0                0        0             1                0
# 227               0                1        1             0                0
# 228               0                1        1             0                1
# 229               1                0        1             0                1
# 230               0                1        1             0                1
# 231               0                1        1             0                1
# 232               1                0        1             1                0
# 233               0                1        0             0                0
# 234               0                1        1             0                1
# 235               0                0        0             0                0
# 237               1                0        1             0                1
# 238               0                0        0             0                0
# 239               0                0        1             0                1
# 240               0                0        0             0                0
# 241               0                0        1             0                1
# 242               0                1        1             0                1
# 243               0                0        0             0                0
# 244               0                1        0             0                0
# 245               0                0        0             0                0
# 246               0                0        1             0                1
# 247               0                0        1             1                1
# 248               0                1        0             0                0
# 249               0                1        1             0                1
# 250               0                0        0             0                0
#
#      partial paresis  muscle stiffness  Alopecia  class
# 0                  0                 1         1      1
# 1                  1                 0         1      1
# 2                  0                 1         1      1
# 3                  0                 0         0      1
# 4                  1                 1         1      1
# 5                  0                 1         1      1
# 6                  1                 0         0      1
# 7                  1                 1         0      1
# 8                  1                 1         0      1
# 9                  0                 0         1      1
# 10                 0                 1         1      1
# 11                 0                 1         0      1
# 12                 0                 0         1      1
# 13                 0                 0         1      1
# 14                 1                 0         0      1
# 15                 1                 1         0      1
# 16                 0                 1         0      1
# 17                 1                 1         1      1
# 18                 1                 1         0      1
# 19                 0                 0         0      1
# 20                 1                 1         0      1
# 21                 0                 1         1      1
# 22                 0                 0         1      1
# 23                 0                 0         0      1
# 24                 1                 1         0      1
# 25                 0                 0         0      1
# 26                 0                 1         0      1
# 27                 1                 1         0      1
# 28                 0                 0         1      1
# 29                 1                 0         1      1
# ..               ...               ...       ...    ...
# 220                0                 0         0      0
# 221                0                 1         1      0
# 222                0                 0         1      0
# 223                0                 0         0      0
# 224                0                 0         1      0
# 225                0                 1         1      0
# 226                1                 0         0      0
# 227                0                 1         0      0
# 228                0                 1         1      0
# 229                0                 0         1      0
# 230                0                 1         1      0
# 231                0                 0         1      0
# 232                0                 0         1      1
# 233                0                 1         0      0
# 234                1                 1         1      0
# 235                0                 0         0      0
# 237                0                 0         1      0
# 238                0                 0         0      0
# 239                0                 1         1      0
# 240                0                 0         0      0
# 241                0                 0         1      0
# 242                1                 1         1      0
# 243                0                 0         1      0
# 244                1                 0         0      1
# 245                1                 0         0      1
# 246                1                 0         0      1
# 247                1                 0         0      1
# 248                1                 1         0      1
# 249                0                 0         1      0
# 250                0                 0         0      0
#
# [247 rows x 15 columns]

# %%
data = dataset_diabetes.drop_duplicates()

# %%
data.to_csv("diabetes.csv", index=False)

# %%
data['class'].value_counts()
# Out:
# 1    171
# 0     76
# Name: class, dtype: int64

# %%
data['Gender'] = data['Gender'].map({'Male':1,'Female':0}) # Binary Encoding, a type of encoding for categorical data # Handling Categorical Values
data['class'] = data['class'].map({'Positive':1,'Negative':0})
data['Polyuria'] = data['Polyuria'].map({'Yes':1,'No':0})
data['Polydipsia'] = data['Polydipsia'].map({'Yes':1,'No':0})
data['sudden weight loss'] = data['sudden weight loss'].map({'Yes':1,'No':0})
data['weakness'] = data['weakness'].map({'Yes':1,'No':0})
data['Polyphagia'] = data['Polyphagia'].map({'Yes':1,'No':0})
data['Genital thrush'] = data['Genital thrush'].map({'Yes':1,'No':0})
data['visual blurring'] = data['visual blurring'].map({'Yes':1,'No':0})
data['Itching'] = data['Itching'].map({'Yes':1,'No':0})
data['Irritability'] = data['Irritability'].map({'Yes':1,'No':0})
data['delayed healing'] = data['delayed healing'].map({'Yes':1,'No':0})
data['partial paresis'] = data['partial paresis'].map({'Yes':1,'No':0})
data['muscle stiffness'] = data['muscle stiffness'].map({'Yes':1,'No':0})
data['Alopecia'] = data['Alopecia'].map({'Yes':1,'No':0})
data['Obesity'] = data['Obesity'].map({'Yes':1,'No':0})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weakness'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-c9eb524c43fe> in <module>
#       4 data['Polydipsia'] = data['Polydipsia'].map({'Yes':1,'No':0})
#       5 data['sudden weight loss'] = data['sudden weight loss'].map({'Yes':1,'No':0})
# ----> 6 data['weakness'] = data['weakness'].map({'Yes':1,'No':0})
#       7 data['Polyphagia'] = data['Polyphagia'].map({'Yes':1,'No':0})
#       8 data['Genital thrush'] = data['Genital thrush'].map({'Yes':1,'No':0})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weakness'

# %%
data.to_csv("diabetes.csv", index=False)

# %%
data.describe() # statistical details like percentile, mean, std etc. (numerical values)

# %%
display(data.describe(percentiles = [0.25,0.5,0.75,0.85,0.95,0.99])) # More detailed percentile values
# Eg. 25th Percentile - 65
# 75% of the data is having the value above 65
# Out:
#               Age  Gender  Polyuria  Polydipsia  sudden weight loss  \
# count  247.000000     0.0       0.0         0.0                 0.0
# mean    49.032389     NaN       NaN         NaN                 NaN
# std     12.521809     NaN       NaN         NaN                 NaN
# min     16.000000     NaN       NaN         NaN                 NaN
# 25%     39.000000     NaN       NaN         NaN                 NaN
# 50%     48.000000     NaN       NaN         NaN                 NaN
# 75%     58.000000     NaN       NaN         NaN                 NaN
# 85%     63.100000     NaN       NaN         NaN                 NaN
# 95%     68.000000     NaN       NaN         NaN                 NaN
# 99%     75.780000     NaN       NaN         NaN                 NaN
# max     90.000000     NaN       NaN         NaN                 NaN
#
#        Polyphagia  Genital thrush  visual blurring     Itching  Irritability  \
# count  247.000000      247.000000       247.000000  247.000000    247.000000
# mean     0.465587        0.271255         0.441296    0.514170      0.283401
# std      0.499827        0.445510         0.497550    0.500814      0.451564
# min      0.000000        0.000000         0.000000    0.000000      0.000000
# 25%      0.000000        0.000000         0.000000    0.000000      0.000000
# 50%      0.000000        0.000000         0.000000    1.000000      0.000000
# 75%      1.000000        1.000000         1.000000    1.000000      1.000000
# 85%      1.000000        1.000000         1.000000    1.000000      1.000000
# 95%      1.000000        1.000000         1.000000    1.000000      1.000000
# 99%      1.000000        1.000000         1.000000    1.000000      1.000000
# max      1.000000        1.000000         1.000000    1.000000      1.000000
#
#        delayed healing  partial paresis  muscle stiffness    Alopecia  class
# count       247.000000       247.000000        247.000000  247.000000    0.0
# mean          0.502024         0.445344          0.392713    0.364372    NaN
# std           0.501011         0.498013          0.489345    0.482231    NaN
# min           0.000000         0.000000          0.000000    0.000000    NaN
# 25%           0.000000         0.000000          0.000000    0.000000    NaN
# 50%           1.000000         0.000000          0.000000    0.000000    NaN
# 75%           1.000000         1.000000          1.000000    1.000000    NaN
# 85%           1.000000         1.000000          1.000000    1.000000    NaN
# 95%           1.000000         1.000000          1.000000    1.000000    NaN
# 99%           1.000000         1.000000          1.000000    1.000000    NaN
# max           1.000000         1.000000          1.000000    1.000000    NaN

# %%
data[data.index.duplicated(keep = 'last')] # Column names only
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Polyuria, Polydipsia, sudden weight loss, Polyphagia, Genital thrush, visual blurring, Itching, Irritability, delayed healing, partial paresis, muscle stiffness, Alopecia, class]
# Index: []

# %%
data.skew() # Skewness
# Out:
# Age                   0.199179
# Gender                     NaN
# Polyuria                   NaN
# Polydipsia                 NaN
# sudden weight loss         NaN
# Polyphagia            0.138823
# Genital thrush        1.035273
# visual blurring       0.237900
# Itching              -0.057050
# Irritability          0.967159
# delayed healing      -0.008147
# partial paresis       0.221288
# muscle stiffness      0.442073
# Alopecia              0.567092
# class                      NaN
# dtype: float64

# %%
data['Irritability'].plot(kind = 'density')
print('This distribution has skew', data['Irritability'].skew())
# Out:
# This distribution has skew 0.9671594292940263

# %%
data['delayed healing'].plot(kind = 'density')
print('This distribution has skew', data['delayed healing'].skew())
# Out:
# This distribution has skew -0.00814679048548309

# %%
data.kurt()
# Out:
# Age                  -0.342840
# Gender                     NaN
# Polyuria                   NaN
# Polydipsia                 NaN
# sudden weight loss         NaN
# Polyphagia           -1.996964
# Genital thrush       -0.935854
# visual blurring      -1.959335
# Itching              -2.013112
# Irritability         -1.073360
# delayed healing      -2.016327
# partial paresis      -1.967025
# muscle stiffness     -1.819369
# Alopecia             -1.692175
# class                      NaN
# dtype: float64

# %%
data['Itching'].plot(kind = 'density')
print('This distribution has kurtosis', data['Itching'].kurt())
# Out:
# This distribution has kurtosis -2.0131121724538534

# %%
data['Obesity'].plot(kind = 'density')
print('This distribution has kurtosis', data['Obesity'].kurt())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Obesity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-0d7afd4f165d> in <module>
# ----> 1 data['Obesity'].plot(kind = 'density')
#       2 print('This distribution has kurtosis', data['Obesity'].kurt())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Obesity'

# %%
Corr = data.corr() # Pairwise correlation of all the columns in the dataframe
print(Corr)
Corr = pd.DataFrame(Corr)
Corr.to_csv('out.csv')
# Out:
#                          Age  Gender  Polyuria  Polydipsia  \
# Age                 1.000000     NaN       NaN         NaN
# Gender                   NaN     NaN       NaN         NaN
# Polyuria                 NaN     NaN       NaN         NaN
# Polydipsia               NaN     NaN       NaN         NaN
# sudden weight loss       NaN     NaN       NaN         NaN
# Polyphagia          0.199575     NaN       NaN         NaN
# Genital thrush      0.097520     NaN       NaN         NaN
# visual blurring     0.376782     NaN       NaN         NaN
# Itching             0.243657     NaN       NaN         NaN
# Irritability        0.178099     NaN       NaN         NaN
# delayed healing     0.200858     NaN       NaN         NaN
# partial paresis     0.202363     NaN       NaN         NaN
# muscle stiffness    0.287163     NaN       NaN         NaN
# Alopecia            0.288859     NaN       NaN         NaN
# class                    NaN     NaN       NaN         NaN
#
#                     sudden weight loss  Polyphagia  Genital thrush  \
# Age                                NaN    0.199575        0.097520
# Gender                             NaN         NaN             NaN
# Polyuria                           NaN         NaN             NaN
# Polydipsia                         NaN         NaN             NaN
# sudden weight loss                 NaN         NaN             NaN
# Polyphagia                         NaN    1.000000       -0.058313
# Genital thrush                     NaN   -0.058313        1.000000
# visual blurring                    NaN    0.265637       -0.120427
# Itching                            NaN    0.127811        0.082909
# Irritability                       NaN    0.187469        0.202309
# delayed healing                    NaN    0.215366        0.152333
# partial paresis                    NaN    0.306779       -0.143607
# muscle stiffness                   NaN    0.296468       -0.061752
# Alopecia                           NaN   -0.015226        0.181400
# class                              NaN         NaN             NaN
#
#                     visual blurring   Itching  Irritability  delayed healing  \
# Age                        0.376782  0.243657      0.178099         0.200858
# Gender                          NaN       NaN           NaN              NaN
# Polyuria                        NaN       NaN           NaN              NaN
# Polydipsia                      NaN       NaN           NaN              NaN
# sudden weight loss              NaN       NaN           NaN              NaN
# Polyphagia                 0.265637  0.127811      0.187469         0.215366
# Genital thrush            -0.120427  0.082909      0.202309         0.152333
# visual blurring            1.000000  0.260292      0.038164         0.167628
# Itching                    0.260292  1.000000      0.036096         0.360357
# Irritability               0.038164  0.036096      1.000000         0.069326
# delayed healing            0.167628  0.360357      0.069326         1.000000
# partial paresis            0.286398  0.104984      0.123386         0.143001
# muscle stiffness           0.303773  0.201128      0.174951         0.253745
# Alopecia                   0.055628  0.197349      0.083891         0.232489
# class                           NaN       NaN           NaN              NaN
#
#                     partial paresis  muscle stiffness  Alopecia  class
# Age                        0.202363          0.287163  0.288859    NaN
# Gender                          NaN               NaN       NaN    NaN
# Polyuria                        NaN               NaN       NaN    NaN
# Polydipsia                      NaN               NaN       NaN    NaN
# sudden weight loss              NaN               NaN       NaN    NaN
# Polyphagia                 0.306779          0.296468 -0.015226    NaN
# Genital thrush            -0.143607         -0.061752  0.181400    NaN
# visual blurring            0.286398          0.303773  0.055628    NaN
# Itching                    0.104984          0.201128  0.197349    NaN
# Irritability               0.123386          0.174951  0.083891    NaN
# delayed healing            0.143001          0.253745  0.232489    NaN
# partial paresis            1.000000          0.196857 -0.204490    NaN
# muscle stiffness           0.196857          1.000000  0.045751    NaN
# Alopecia                  -0.204490          0.045751  1.000000    NaN
# class                           NaN               NaN       NaN    NaN

# %%
f,ax = plt.subplots(figsize=(9, 9))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(9, 9))
sns.heatmap(data.cov(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %% [markdown]
# # Feature Selection

# %%
X1 = data.iloc[:,0:-1]
y1 = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X1,y1,test_size = 0.2,random_state=0)

# %%
# Recursive feature elimination with cross validation (RFECV) and random forest classification
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
clf_rf_4 = RandomForestClassifier() 
rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')   #5-fold cross-validation
rfecv = rfecv.fit(X_train, y_train)

print('Optimal number of features :', rfecv.n_features_)
print('Best features :', X_train.columns[rfecv.support_])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-48cc8e98eeeb> in <module>
#       4 clf_rf_4 = RandomForestClassifier()
#       5 rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')   #5-fold cross-validation
# ----> 6 rfecv = rfecv.fit(X_train, y_train)
#       7
#       8 print('Optimal number of features :', rfecv.n_features_)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\rfe.py in fit(self, X, y, groups)
#     472             train/test set.
#     473         """
# --> 474         X, y = check_X_y(X, y, "csr")
#     475
#     476         # Initialization
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Plot number of features VS. cross-validation scores
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score of number of selected features")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
data.drop('weakness',axis = 1,inplace = True) # dropping of the "weakness" feature from the dataset
data.to_csv("diabetes.csv", index = False) # Modifying the dataset after dropping "weakness" feature

# %%
data.drop('Obesity',axis = 1,inplace = True) # dropping of the "weakness" feature from the dataset
data.to_csv("diabetes.csv", index = False) # Modifying the dataset after dropping "weakness" feature

# %%
from pandas import read_csv #  imports a CSV file to DataFrame format.
data = read_csv('diabetes.csv')# read csv

# %% [markdown]
# # Model Building

# %%
X1 = data.iloc[:,0:-1]
y1 = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X1,y1,test_size = 0.2,random_state=0)

# %%
# Building of Logistic Regression Model
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# Predicting the values of X_test
y_pred = lg.predict(X_test)

# %% [markdown]
# # Model Evaluation

# %%
# Generation of confusion matrix and classification report with accuracy, precsion, recall, f1-score and support
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[10  3]
#  [ 3 35]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        13
#            1       0.92      0.92      0.92        38
#
#    micro avg       0.88      0.88      0.88        51
#    macro avg       0.85      0.85      0.85        51
# weighted avg       0.88      0.88      0.88        51

# %%
cmlg=confusion_matrix(y_test, y_pred) # Confusion Matrix before scaling

# %%
f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cmlg,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_test")
plt.show()

# %%
from sklearn import svm
svm_classifier = svm.SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_predict = svm_classifier.predict(X_test)

# %%
print(confusion_matrix(y_test, y_predict))
print(classification_report(y_test, y_predict))
# Out:
# [[ 9  4]
#  [ 0 38]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.69      0.82        13
#            1       0.90      1.00      0.95        38
#
#    micro avg       0.92      0.92      0.92        51
#    macro avg       0.95      0.85      0.88        51
# weighted avg       0.93      0.92      0.92        51

# %%
cmknn=confusion_matrix(y_test, y_predict)

# %%
f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cmknn,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_test")
plt.show()

# %% [markdown]
# # Feature Scaling and Model Building

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X1) # Feature scaling with standardization
X_std
# Out:
# array([[-0.70910328,  0.75415516, -1.05320639, ..., -0.89763879,
#          1.24948969,  1.33749351],
#        [ 0.73077475,  0.75415516, -1.05320639, ...,  1.11403385,
#         -0.80032673,  1.33749351],
#        [-0.62911006,  0.75415516,  0.94948152, ..., -0.89763879,
#          1.24948969,  1.33749351],
#        ...,
#        [ 0.73077475, -1.32598709,  0.94948152, ...,  1.11403385,
#          1.24948969, -0.74766718],
#        [-1.34904907, -1.32598709, -1.05320639, ..., -0.89763879,
#         -0.80032673,  1.33749351],
#        [-0.54911683,  0.75415516, -1.05320639, ..., -0.89763879,
#         -0.80032673, -0.74766718]])

# %%
from sklearn.model_selection import train_test_split
Xstd_train,Xstd_test,ystd_train,ystd_test = train_test_split(X_std,y1,test_size = 0.2,random_state=0) # splitting of training and testing

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(Xstd_train,ystd_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = lg.predict(Xstd_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(ystd_test, y_pred))
print(classification_report(ystd_test, y_pred))
# Out:
# [[11  2]
#  [ 5 33]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.85      0.76        13
#            1       0.94      0.87      0.90        38
#
#    micro avg       0.86      0.86      0.86        51
#    macro avg       0.82      0.86      0.83        51
# weighted avg       0.88      0.86      0.87        51

# %%
from sklearn import svm
classifier = svm.SVC(kernel='rbf')
classifier.fit(Xstd_train, ystd_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_predict = classifier.predict(Xstd_test)

# %%
print(confusion_matrix(ystd_test, y_predict))
print(classification_report(ystd_test, y_predict))
# Out:
# [[12  1]
#  [ 1 37]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        13
#            1       0.97      0.97      0.97        38
#
#    micro avg       0.96      0.96      0.96        51
#    macro avg       0.95      0.95      0.95        51
# weighted avg       0.96      0.96      0.96        51
